# 51  ...               0.137017   0.115229    0.071344     -0.15088
# 52  ...
# 53  ...
#
#     asr_som_ts1_A  DemographicFSIQ  RES_CD4  RES_TNF  RES_DI  RES_VI
# 0              50               93  -437.56     9.90   -0.38   -0.05
# 1              50               77  -157.15     8.76   -0.50    0.16
# 2              69               82  -228.55    -2.61    0.09    0.28
# 3              64              112    61.02    -3.55   -0.15   -0.04
# 4              67               97    67.36    -2.46    0.03   -0.01
# 5              50               93    94.81    -5.48    0.26    0.06
# 6              57               88   -47.84     1.18    0.12    0.19
# 7              50              101  -408.01     3.87    0.09   -0.13
# 8              53               95   534.49    -4.70    0.24   -0.03
# 9              50               73   -99.52    -3.46   -0.19   -0.29
# 10             50              117  -100.83     3.79   -0.29    0.09
# 11             55              101    82.75    -4.11    0.51   -0.03
# 12             52              110    65.66     4.64   -0.14   -0.10
# 13             64               85   301.69     2.00    0.31    0.01
# 14             50               92  -269.94    -2.18    0.28   -0.07
# 15             52              102   105.12    -3.72    0.08    0.09
# 16             52              122  -492.81    22.61    0.00    0.01
# 17             55               88   189.21    -1.84   -0.80   -0.06
# 18             62              111     2.03    -2.17   -0.18    0.03
# 19             74               93  -203.05    -6.12    0.61   -0.04
# 20             50              108   -82.06    -4.06    0.33    0.35
# 21             62               93    91.98     3.65    0.19    0.02
# 22             60              103  -222.47     7.22    0.24    0.03
# 23             64               96     7.81     1.31   -0.07   -0.08
# 24             60              110   177.82    -7.55    0.32   -0.02
# 25             58              112  -204.17    -1.73    0.53   -0.18
# 26             50              102   403.51    -7.77    0.01   -0.08
# 27             51              121   220.88    -6.43   -0.24   -0.08
# 28             50               89  -465.46    10.28   -0.87    0.10
# 29             58              104   217.70    -1.95    0.42   -0.15
# 30             81              105    42.14    -5.64    0.07   -0.10
# 31             64              103   402.97    -6.82    0.04    0.00
# 32             50               94   -49.32     5.13   -0.16    0.14
# 33             53               80   859.97    -4.06    0.02    0.05
# 34             55              102    51.77    -4.18   -0.14   -0.05
# 35             50              117  -210.81    -4.42    0.12    0.04
# 36             50              106   128.53     6.11   -0.66   -0.04
# 37             50               81  -255.55     1.13   -0.03    0.12
# 38             76              103  -198.74     9.54    0.02    0.03
# 39             52              110  -214.48     1.73    0.31   -0.13
# 40             60               97   499.87    -3.45   -0.12   -0.10
# 41             50              109  -570.01     4.76   -0.40    0.16
# 42             50              104   481.15    -8.43   -0.04    0.11
# 43             59               85   -59.84    -3.21   -0.17   -0.03
# 44             63               93   264.41    -2.05   -0.35   -0.06
# 45             65              100   -30.44    -4.47   -0.03   -0.05
# 46             52               77   524.73    10.90   -0.42    0.03
# 47             58               88  -245.20     6.07    0.23   -0.02
# 48             50              103  -371.16     0.73   -0.07    0.00
# 49             50               87    87.64    -4.87    0.20   -0.02
# 50             56               81  -200.69    -1.39    0.71   -0.13
# 51             54               88  -141.37    -0.44    0.04    0.05
# 52                                      NaN      NaN     NaN     NaN
# 53                                      NaN      NaN     NaN     NaN
#
# [54 rows x 62 columns]

# %%
df[['hiv', 'cb']]
df['HIV-status'] = df['hiv'].map({0: 'HIV-', 1: 'HIV+'})
df['CB-status'] = df['cb'].map({0: 'non-user', 1: 'user'})
df['group'] = df['HIV-status'] + ', ' + df['CB-status']

# We need a separate dataframe for each group
hiv_pos_df = df.loc[df['HIV-status'] == 'HIV+']
hiv_neg_df = df.loc[df['HIV-status'] == 'HIV-']

# %%
hiv_pos_df
# Out:
#       id  hiv  cb           group  age  sex  lab_wbc  lab_cd45  lab_tlym  \
# 0   P206    1   1      HIV+, user   42    2     5200      1846      1514
# 1   P211    1   0  HIV+, non-user   20    1     3000      1680      1478
# 2   P216    1   0  HIV+, non-user   19    2     4800      1747      1206
# 3   P225    1   1      HIV+, user   45    1     5800      2001      1541
# 4   P229    1   1      HIV+, user   43    2     5900      2053      1827
# 5   P237    1   0  HIV+, non-user   25    1     7000      2541      2160
# 6   P238    1   0  HIV+, non-user   35    1     9600      1690      1335
# 7   P242    1   0  HIV+, non-user   29    2     5100      1204       830
# 8   P244    1   0  HIV+, non-user   40    2     9200      3036      2763
# 9   p247    1   0  HIV+, non-user   23    1     4900      2200      1754
# 10  P248    1   0  HIV+, non-user   31    1     6100      2208      1921
# 11  P253    1   0  HIV+, non-user   34    1     6600      2125      1509
# 12  P257    1   1      HIV+, user   25    2     7800      2675      2301
# 13  P259    1   1      HIV+, user   39    2     6900      2450      1715
# 14  P263    1   0  HIV+, non-user   23    1     5200      1867      1288
# 15  P268    1   1      HIV+, user   27    1     8700      1853      1538
# 16  P273    1   1      HIV+, user   25    1     2600      1144      1007
# 17  P280    1   0  HIV+, non-user   18    1     6700      2110      1731
# 18  P282    1   1      HIV+, user   26    1     5500      1947      1538
# 19  P294    1   0  HIV+, non-user   31    1     6200      2492      1844
# 20  P297    1   1      HIV+, user   30    1     2900      1598      1294
# 21  P299    1   0  HIV+, non-user   39    1     8300      2946      1945
# 22  P300    1   1      HIV+, user   28    1     4800      1766      1466
# 23  P301    1   0  HIV+, non-user   28    1    10800      2776      2470
# 24  P302    1   1      HIV+, user   47    2     5000      2645      2195
# 25  P306    1   0  HIV+, non-user   56    1     8600      3225      2774
# 26  P309    1   1      HIV+, user   24    1    11200      2061      1896
# 27  P310    1   1      HIV+, user   38    1     6500      2314      1712
# 28  P311    1   0  HIV+, non-user   53    1     7200      1872      1554
# 29  P313    1   0  HIV+, non-user   28    1     5400      2338      1660
# 30  P316    1   1      HIV+, user   29    1     3200      1552      1117
# 31  P324    1   1      HIV+, user   29    1     8200      2460      1820
# 32  P326    1   1      HIV+, user   46    1     5700      3238      2720
# 33  P328    1   0  HIV+, non-user   46    2     7800      3299      2178
# 34  P331    1   1      HIV+, user   42    2     8000      2320      1902
# 35  P332    1   1      HIV+, user   28    2     7300      1986      1489
# 36  P341    1   0  HIV+, non-user   60    2     6100      2507      1905
# 37  P343    1   0  HIV+, non-user   50    2     5400      2446      1419
# 38  P344    1   1      HIV+, user   45    1     7600      2394      1939
# 39  P345    1   1      HIV+, user   32    1     4800      1320       818
# 40  P346    1   1      HIV+, user   31    1     7700      2348      1738
# 41  P348    1   1      HIV+, user   29    1     4100       607       334
# 42  P351    1   0  HIV+, non-user   51    1     6100      2495      1971
# 43  P358    1   0  HIV+, non-user   46    1     4600      1086       814
# 44  P360    1   1      HIV+, user   29    1     7700      2518      1964
# 45  P363    1   1      HIV+, user   29    2     4400      2402      2018
# 46  P365    1   0  HIV+, non-user   24    1    11500      6152      4922
# 47  P366    1   1      HIV+, user   30    2     5100      3779      3099
# 48  P373    1   0  HIV+, non-user   46    2     8100      2033      1565
# 49  P375    1   1      HIV+, user   30    1     7600      2371      1731
# 50  P383    1   0  HIV+, non-user   47    1     8400      3343      1906
# 51  P389    1   0  HIV+, non-user   59    1     7400      1397      1140
# 52  P392    1   1      HIV+, user   26    2     7600      2903      2119
# 53  P397    1   1      HIV+, user   37    1     4900      2391      2056
#
#     lab_thel  ...  prim_motor  pre_central  asr_som_ts1_A  DemographicFSIQ  \
# 0        258  ...   -0.053833    -0.463826             50               93
# 1        504  ...    0.072271     0.761794             50               77
# 2        612  ...    0.268794     0.094561             69               82
# 3        640  ...   -0.063779     -0.01398             64              112
# 4        780  ...   -0.028396      0.01203             67               97
# 5        737  ...    0.187742     0.351661             50               93
# 6        591  ...    0.403077    -0.184347             57               88
# 7        397  ...   -0.165612     0.566925             50              101
# 8       1245  ...   -0.024483     0.209925             53               95
# 9        577  ...    0.092465     0.635528             50               73
# 10       530  ...    0.353297     0.061858             50              117
# 11       659  ...    0.158955     0.391697             55              101
# 12       829  ...   -0.031071     0.968635             52              110
# 13       980  ...    0.137749     0.305322             64               85
# 14       373  ...     0.24528     0.155165             50               92
# 15       723  ...    0.028272     0.305161             52              102
# 16       137  ...   -0.001678     0.064999             52              122
# 17       823  ...   -0.143462     0.068735             55               88
# 18       643  ...    0.091535     0.252505             62              111
# 19       424  ...    0.100476    -0.110509             74               93
# 20       527  ...    0.368325     0.721081             50              108
# 21       707  ...    0.134738    -0.092762             62               93
# 22       406  ...    0.051316     0.143132             60              103
# 23       666  ...   -0.053699    -0.216861             64               96
# 24       899  ...    0.046065     0.001347             60              110
# 25       290  ...    0.220541    -0.001287             58              112
# 26      1030  ...    -0.13254      0.02423             50              102
# 27       810  ...   -0.098254     -0.16266             51              121
# 28        94  ...    0.196032     0.001319             50               89
# 29       889  ...   -0.254244    -0.554797             58              104
# 30       636  ...   -0.104351    -0.000218             81              105
# 31      1033  ...    0.119002    -0.031604             64              103
# 32       486  ...    0.654337     0.300724             50               94
# 33      1617  ...    0.165333     0.059049             53               80
# 34       789  ...    0.063643    -0.245816             55              102
# 35       536  ...    -0.00565     0.051931             50              117
# 36       802  ...   -0.002421     0.666298             50              106
# 37       416  ...    -0.22523    -0.626638             50               81
# 38       359  ...   -0.064475     0.172215             76              103
# 39       396  ...     0.18724     0.307366             52              110
# 40      1080  ...   -0.186744    -0.270158             60               97
# 41        12  ...    0.488416    -0.116655             50              109
# 42      1023  ...    0.248925     0.310165             50              104
# 43       521  ...   -0.355443    -0.092571             59               85
# 44       881  ...    0.234118    -0.609869             63               93
# 45       721  ...   -0.020734     0.107024             65              100
# 46      1169  ...     0.33173    -0.061896             52               77
# 47       529  ...   -0.018957    -0.004228             58               88
# 48       366  ...    0.240231     0.321268             50              103
# 49       688  ...    0.176949    -0.256179             50               87
# 50       368  ...    0.179717    -0.157154             56               81
# 51       381  ...    0.071344     -0.15088             54               88
# 52       958  ...
# 53      1052  ...
#
#     RES_CD4  RES_TNF  RES_DI  RES_VI  HIV-status  CB-status
# 0   -437.56     9.90   -0.38   -0.05        HIV+       user
# 1   -157.15     8.76   -0.50    0.16        HIV+   non-user
# 2   -228.55    -2.61    0.09    0.28        HIV+   non-user
# 3     61.02    -3.55   -0.15   -0.04        HIV+       user
# 4     67.36    -2.46    0.03   -0.01        HIV+       user
# 5     94.81    -5.48    0.26    0.06        HIV+   non-user
# 6    -47.84     1.18    0.12    0.19        HIV+   non-user
# 7   -408.01     3.87    0.09   -0.13        HIV+   non-user
# 8    534.49    -4.70    0.24   -0.03        HIV+   non-user
# 9    -99.52    -3.46   -0.19   -0.29        HIV+   non-user
# 10  -100.83     3.79   -0.29    0.09        HIV+   non-user
# 11    82.75    -4.11    0.51   -0.03        HIV+   non-user
# 12    65.66     4.64   -0.14   -0.10        HIV+       user
# 13   301.69     2.00    0.31    0.01        HIV+       user
# 14  -269.94    -2.18    0.28   -0.07        HIV+   non-user
# 15   105.12    -3.72    0.08    0.09        HIV+       user
# 16  -492.81    22.61    0.00    0.01        HIV+       user
# 17   189.21    -1.84   -0.80   -0.06        HIV+   non-user
# 18     2.03    -2.17   -0.18    0.03        HIV+       user
# 19  -203.05    -6.12    0.61   -0.04        HIV+   non-user
# 20   -82.06    -4.06    0.33    0.35        HIV+       user
# 21    91.98     3.65    0.19    0.02        HIV+   non-user
# 22  -222.47     7.22    0.24    0.03        HIV+       user
# 23     7.81     1.31   -0.07   -0.08        HIV+   non-user
# 24   177.82    -7.55    0.32   -0.02        HIV+       user
# 25  -204.17    -1.73    0.53   -0.18        HIV+   non-user
# 26   403.51    -7.77    0.01   -0.08        HIV+       user
# 27   220.88    -6.43   -0.24   -0.08        HIV+       user
# 28  -465.46    10.28   -0.87    0.10        HIV+   non-user
# 29   217.70    -1.95    0.42   -0.15        HIV+   non-user
# 30    42.14    -5.64    0.07   -0.10        HIV+       user
# 31   402.97    -6.82    0.04    0.00        HIV+       user
# 32   -49.32     5.13   -0.16    0.14        HIV+       user
# 33   859.97    -4.06    0.02    0.05        HIV+   non-user
# 34    51.77    -4.18   -0.14   -0.05        HIV+       user
# 35  -210.81    -4.42    0.12    0.04        HIV+       user
# 36   128.53     6.11   -0.66   -0.04        HIV+   non-user
# 37  -255.55     1.13   -0.03    0.12        HIV+   non-user
# 38  -198.74     9.54    0.02    0.03        HIV+       user
# 39  -214.48     1.73    0.31   -0.13        HIV+       user
# 40   499.87    -3.45   -0.12   -0.10        HIV+       user
# 41  -570.01     4.76   -0.40    0.16        HIV+       user
# 42   481.15    -8.43   -0.04    0.11        HIV+   non-user
# 43   -59.84    -3.21   -0.17   -0.03        HIV+   non-user
# 44   264.41    -2.05   -0.35   -0.06        HIV+       user
# 45   -30.44    -4.47   -0.03   -0.05        HIV+       user
# 46   524.73    10.90   -0.42    0.03        HIV+   non-user
# 47  -245.20     6.07    0.23   -0.02        HIV+       user
# 48  -371.16     0.73   -0.07    0.00        HIV+   non-user
# 49    87.64    -4.87    0.20   -0.02        HIV+       user
# 50  -200.69    -1.39    0.71   -0.13        HIV+   non-user
# 51  -141.37    -0.44    0.04    0.05        HIV+   non-user
# 52      NaN      NaN     NaN     NaN        HIV+       user
# 53      NaN      NaN     NaN     NaN        HIV+       user
#
# [54 rows x 64 columns]

# %%
# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='RES_DI', y='RES_TNF', data=hiv_pos_df, kind='reg',
                      height=6, color='purple', label='HIV+',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white')), ci=False,
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}), # you can control axes with dicts
                      xlim=(-50, 50), ylim=(-50, 50), truncate=False)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='RES_DI', y='RES_TNF', data=df, ax=ax_joint,
            color='darkslategray', label='all', scatter=False, scatter_kws=dict(edgecolor='white', linewidth=0.6), ci=False, truncate=False)


# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([-1, -0.5, 0, 0.5, 1])
ax_joint.set_xlim(-1,1)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_yticks([-14, -8, 0, 8, 14])
ax_joint.set_ylim(-14,14)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.lines[0].set_linestyle("")
ax_joint.set_xlabel('rsFC | covar', fontsize=16, fontweight='bold')
ax_joint.set_ylabel('TNF-'r'$\alpha$ | covar', fontsize=16, fontweight='bold')
fig.set_size_inches((4.5, 4))
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.tight_layout()
fig.savefig(fname='./RES_DI_TNF')
fig.show()

#######################################################################
# Out:
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='RES_DI', y='RES_CD4', data=hiv_pos_df, kind='reg',
                      height=6, color='purple', label='HIV+',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white')), ci=False,
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}), # you can control axes with dicts
                      xlim=(-5000, 5000), ylim=(-5000, 5000), truncate=False)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='RES_DI', y='RES_CD4', data=df, ax=ax_joint,
            color='darkslategray', label='all', scatter=False, scatter_kws=dict(edgecolor='white', linewidth=0.6), ci=False, truncate=False)


# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([-1, -0.5, 0, 0.5, 1])
ax_joint.set_xlim(-1,1)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_yticks([-800, -400, 0, 400, 800])
ax_joint.set_ylim(-800,800)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle(":")
ax_joint.set_xlabel('rsFC | covar', fontsize=16, fontweight='bold')
ax_joint.set_ylabel('CD4+ CELL COUNT | covar', fontsize=16, fontweight='bold')
fig.set_size_inches((4.5, 4))
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.tight_layout()
fig.savefig(fname='./RES_DI_CD4')
fig.show()

#######################################################################
# Out:
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='RES_VI', y='RES_TNF', data=hiv_pos_df, kind='reg',
                      height=6, color='purple', label='HIV+',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white')), ci=False,
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}), # you can control axes with dicts
                      xlim=(-50, 50), ylim=(-50, 50), truncate=False)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='RES_VI', y='RES_TNF', data=df, ax=ax_joint,
            color='darkslategray', label='all', scatter=False, scatter_kws=dict(edgecolor='white', linewidth=0.6), ci=False, truncate=False)


# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([-0.5, -0.3, -0.1, 0.1, 0.3, 0.5])
ax_joint.set_xlim(-0.5,0.5)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_yticks([-14, -8, 0, 8, 14])
ax_joint.set_ylim(-14,14)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle(":")
ax_joint.set_xlabel('rsFC | covar', fontsize=16, fontweight='bold')
ax_joint.set_ylabel('TNF-'r'$\alpha$ | covar', fontsize=16, fontweight='bold')
fig.set_size_inches((4.5, 4))
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.tight_layout()
fig.savefig(fname='./RES_VI_TNF')
fig.show()

#######################################################################
# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='RES_VI', y='RES_CD4', data=hiv_pos_df, kind='reg',
                      height=6, color='purple', label='HIV+',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white')), ci=False,
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}), # you can control axes with dicts
                      xlim=(-5000, 5000), ylim=(-5000, 5000), truncate=False)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='RES_VI', y='RES_CD4', data=df, ax=ax_joint,
            color='darkslategray', label='all', scatter=False, scatter_kws=dict(edgecolor='white', linewidth=0.6), ci=False, truncate=False)


# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([-0.5, -0.25, 0, 0.25, 0.5])
ax_joint.set_xlim(-0.5,0.5)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_yticks([-800, -400, 0, 400, 800])
ax_joint.set_ylim(-800,800)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle(":")
ax_joint.set_xlabel('rsFC | covar', fontsize=16, fontweight='bold')
ax_joint.set_ylabel('CD4+ CELL COUNT | covar', fontsize=16, fontweight='bold')
fig.set_size_inches((4.5, 4))
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.tight_layout()
fig.savefig(fname='./RES_VI_CD4')
fig.show()

#######################################################################
# Out:
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:78: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='RES_TNF', y='RES_CD4', data=hiv_pos_df, kind='reg',
                      height=6, color='purple', label='HIV+',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white')), ci=False,
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}), # you can control axes with dicts
                      xlim=(-50, 50), ylim=(-50, 50), truncate=False)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='RES_TNF', y='RES_CD4', data=df, ax=ax_joint,
            color='darkslategray', label='all', scatter=False, scatter_kws=dict(edgecolor='white', linewidth=0.6), ci=False, truncate=False)


# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([-14, -8, 0, 8, 14])
ax_joint.set_xlim(-14,14)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_yticks([-800, -400, 0, 400, 800])
ax_joint.set_ylim(-800,800)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.lines[0].set_linestyle("")
ax_joint.set_xlabel('TNF-'r'$\alpha$ | covar', fontsize=16, fontweight='bold')
ax_joint.set_ylabel('CD4 CELL COUNT | covar', fontsize=16, fontweight='bold')
fig.set_size_inches((4.5, 4))
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.tight_layout()
fig.savefig(fname='./RES_CD4_TNF')
fig.show()

#######################################################################
# Out:
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
