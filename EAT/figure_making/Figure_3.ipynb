# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

sns.set_style('white')
#Input data
in_file = '../data/wholesample_aware_86.csv'
df = pd.read_csv(in_file)

# %%
df['awareness'] = df['awareness'].map({'AWARE': 'aware', 'UNAWARE': 'unaware'})

df.head()
# Out:
#    File awareness  L. Motor Area  R. Insula  R. Putamen    R. PCC    L. PCC  \
# 0  P193     aware       0.161659   0.866227   -1.012094 -1.440477 -2.077463
# 1  P194     aware       0.686032   0.885595    0.159889 -1.563868 -0.955360
# 2  P198     aware       1.410567   1.864419    0.620121  0.052129  0.231726
# 3  P206     aware       1.006954   0.413761   -0.791666 -0.575818 -1.336955
# 4  P211     aware       1.808600   1.320182    0.065682 -0.124719 -0.454664
#
#      R. PFC
# 0 -1.043522
# 1 -0.204226
# 2 -0.097239
# 3 -0.683197
# 4 -0.019354

# %%
pal = sns.color_palette(['teal', 'darkblue'])

fig, ax = plt.subplots(figsize=(4, 3.5))
sns.barplot(y='L. PCC', x='awareness', 
            data=df, ax=ax, capsize=0.1, 
            errcolor='black', ci=95, palette=pal, errwidth=2, linewidth=2.5, edgecolor="black")
def change_width(ax, new_value) :
    locs = ax.get_xticks()
    for i,patch in enumerate(ax.patches):
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
change_width(ax, .4) 
ax.set_ylabel('% BOLD 'r'$\Delta$', fontsize=20, fontweight='bold')
ax.set_xlabel('AWARENESS', fontsize=20, fontweight='bold', labelpad=10)
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_ylim(-1, 1)
ax.tick_params(axis='both', labelsize=16, direction='out', length=5, left=True, width=2.5)
ax.tick_params(axis='x', labelsize=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(2.5)
ax.axhline(0, color='black', linewidth=2.5)
#for tick in ax.xaxis.get_major_ticks():
    #tick.label1.set_fontweight('bold')
fig.tight_layout()
fig.savefig(fname='./figure_3/aware_LPCC_bar.png', dpi=300)

###############   #################

fig, ax = plt.subplots(figsize=(4, 3.5))
sns.barplot(y='R. PFC', x='awareness', 
            data=df, ax=ax, capsize=0.1, 
            errcolor='black', ci=95, palette=pal, errwidth=2, linewidth=2.5, edgecolor="black")
def change_width(ax, new_value) :
    locs = ax.get_xticks()
    for i,patch in enumerate(ax.patches):
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
change_width(ax, .4) 
ax.set_ylabel('% BOLD 'r'$\Delta$', fontsize=20, fontweight='bold')
ax.set_xlabel('AWARENESS', fontsize=20, fontweight='bold', labelpad=10)
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_ylim(-1, 1)
ax.tick_params(axis='both', labelsize=16, direction='out', length=5, left=True, width=2.5)
ax.tick_params(axis='x', labelsize=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(2.5)
ax.axhline(0, color='black', linewidth=2.5)
#for tick in ax.xaxis.get_major_ticks():
    #tick.label1.set_fontweight('bold')
fig.tight_layout()
fig.savefig(fname='./figure_3/aware_RPFC_bar.png', dpi=300)

###############   #################
fig, ax = plt.subplots(figsize=(4, 3.5))
sns.barplot(y='R. Putamen', x='awareness', 
            data=df, ax=ax, capsize=0.1, 
            errcolor='black', ci=95, palette=pal, errwidth=2, linewidth=2.5, edgecolor="black")
def change_width(ax, new_value) :
    locs = ax.get_xticks()
    for i,patch in enumerate(ax.patches):
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
change_width(ax, .4) 
ax.set_ylabel('% BOLD 'r'$\Delta$', fontsize=20, fontweight='bold')
ax.set_xlabel('AWARENESS', fontsize=20, fontweight='bold', labelpad=10)
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_ylim(-1, 1)
ax.tick_params(axis='both', labelsize=16, direction='out', length=5, left=True, width=2.5)
ax.tick_params(axis='x', labelsize=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(2.5)
ax.axhline(0, color='black', linewidth=2.5)
#for tick in ax.xaxis.get_major_ticks():
    #tick.label1.set_fontweight('bold')
fig.tight_layout()
fig.savefig(fname='./figure_3/aware_RPut_bar.png', dpi=300)

###############   #################

fig, ax = plt.subplots(figsize=(4, 3.5))
sns.barplot(y='R. Insula', x='awareness', 
            data=df, ax=ax, capsize=0.1, 
            errcolor='black', ci=95, palette=pal, errwidth=2, linewidth=2.5, edgecolor="black")
def change_width(ax, new_value) :
    locs = ax.get_xticks()
    for i,patch in enumerate(ax.patches):
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
change_width(ax, .4) 

ax.set_ylabel('% BOLD 'r'$\Delta$', fontsize=20, fontweight='bold')
ax.set_xlabel('AWARENESS', fontsize=20, fontweight='bold', labelpad=10)
ax.set_yticks([0, 0.5, 1, 1.5, 2])
ax.set_ylim(0, 2)
ax.tick_params(axis='both', labelsize=16, direction='out', length=5, left=True, width=2.5)
ax.tick_params(axis='x', labelsize=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_linewidth(2.5)
ax.spines['left'].set_linewidth(2.5)
#for tick in ax.xaxis.get_major_ticks():
    #tick.label1.set_fontweight('bold')
fig.tight_layout()
fig.savefig(fname='./figure_3/aware_LPI_bar.png', dpi=300)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

sns.set_style('white')
#Input data
in_file = '../data/wholesample_corr_aware_86.csv'
df = pd.read_csv(in_file)
df.head()
# Out:
#    File  HIV   CB  group  n_nogo_aware  n_nogo_unaware  mean_pre_aware_rt  \
# 0  P193  1.0  1.0    1.0          37.0            13.0           0.431865
# 1  P194  1.0  1.0    1.0          29.0             3.0           0.477759
# 2  P198  1.0  1.0    1.0          84.0            14.0           0.440321
# 3  P206  2.0  2.0    4.0          90.0            38.0           0.408978
# 4  P211  2.0  1.0    3.0         122.0             3.0           0.339270
#
#    mean_post_aware_rt  mean_pre_unaware_rt  mean_post_unaware_rt  ...  \
# 0            0.442486             0.459769              0.430308  ...
# 1            0.428310             0.501667              0.477333  ...
# 2            0.419417             0.442786              0.477857  ...
# 3            0.350700             0.390211              0.431500  ...
# 4            0.298828             0.349000              0.339667  ...
#
#    L_Motor_Area_AU  R_P_Insula_AU  R_Putamen_AU  R_PFC_AU  L_PCC_AU  R_PCC_AU  \
# 0             0.43           0.04         -0.48     -0.58 -0.161780     -0.16
# 1             0.38           0.75          1.11     -1.43  0.643784      0.64
# 2             1.36           1.72          1.46     -0.20 -0.725760     -0.73
# 3            -0.90          -0.76         -0.42     -1.28 -2.507093     -2.51
# 4             1.75           1.10         -0.47      0.93  2.415569      2.42
#
#    percent_unaware  percent_aware  unaware_log10  Unnamed: 66
# 0            24.53          69.81           1.39          NaN
# 1             9.09          87.88           0.96          NaN
# 2            14.29          85.71           1.15          NaN
# 3            27.94          66.18           1.45          NaN
# 4             2.38          96.83           0.38          NaN
#
# [5 rows x 67 columns]

# %%
jgrid = sns.jointplot(x='unaware_log10', y='R_P_Insula_AU', 
                      data=df, kind='reg',
                      height=6, color='darkslategray',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xlim(0,2.5)
ax_joint.set_xticks([0, 0.5, 1, 1.5, 2, 2.5])
ax_joint.lines[0].set_linewidth(3)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_ylim(-2, 4)
ax_joint.set_yticks([-2, 0, 2, 4])
ax_joint.lines[0].set_linestyle(":")
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
# Add a legend
ax_joint.set_xlabel('% UNAWARE (log10)', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/R_PI-AU_unaware')
fig.show()

######################################################################################

jgrid = sns.jointplot(x='unaware_log10', y='R_Putamen_AU', 
                      data=df, kind='reg',
                      height=6, color='darkslategray',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.lines[0].set_linestyle(":")
ax_joint.lines[0].set_linewidth(3)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_xlim(0,2.5)
ax_joint.set_xticks([0, 0.5, 1, 1.5, 2, 2.5])
ax_joint.set_ylim(-2, 4)
ax_joint.set_yticks([-2, 0, 2, 4])
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
# Add a legend
ax_joint.set_xlabel('% UNAWARE (log10)', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/R_put-AU_unaware')
fig.show()

######################################################################################

jgrid = sns.jointplot(x='unaware_log10', y='L_PCC_AU', 
                      data=df, kind='reg',
                      height=6, color='darkslategray',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xlim(0,2.5)
ax_joint.set_xticks([0, 0.5, 1, 1.5, 2, 2.5])
ax_joint.lines[0].set_linewidth(3)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_ylim(-4, 2)
ax_joint.set_yticks([-4, -2, 0, 2])
ax_joint.lines[0].set_linestyle(":")
ax_joint.tick_params(axis='both', which='major', labelsize=16, direction='out', length=5, left=True, bottom=True, width=2.5)
# Add a legend
ax_joint.set_xlabel(r'% UNAWARE (log10)', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/L_PCC-AU_unaware')
fig.show()

######################################################################################

jgrid = sns.jointplot(x='unaware_log10', y='R_PFC_AU', 
                      data=df, kind='reg',
                      height=6, color='darkslategray',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xlim(0,2.5)
ax_joint.set_xticks([0, 0.5, 1, 1.5, 2, 2.5])
ax_joint.lines[0].set_linewidth(3)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_ylim(-4, 2)
ax_joint.set_yticks([-4, -2, 0, 2])
ax_joint.lines[0].set_linestyle(":")
ax_joint.tick_params(axis='both', which='major', labelsize=16, direction='out', length=5, left=True, bottom=True, width=2.5)
# Add a legend
ax_joint.set_xlabel(r'% UNAWARE (log10)', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/R_PFC-AU_unaware')
fig.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:63: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:96: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:129: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

sns.set_style('white')
#Input data
in_file = '../data/cog_fail_86.csv'
df = pd.read_csv(in_file)
df.head()
# Out:
#    File  HIV  CB  ForgetfulnessSum  DistractibilitySum  FalseTriggeringSum  \
# 0  P193    1   1                 5                   7                   2
# 1  P194    1   1                12                  10                   9
# 2  P198    1   1                11                  10                   6
# 3  P212    1   2                11                  15                  10
# 4  P217    1   1                 9                   6                   6
#
#    cog_diff_sum  A_U_Motor_Area  A_U_R_Insula  A_U_R_Putamen  A_U_R_PFC  \
# 0            19            0.43          0.04          -0.48      -0.58
# 1             0            0.38          0.75           1.11      -1.43
# 2            41            1.36          1.72           1.46      -0.20
# 3            61            0.66          0.60          -0.11      -0.76
# 4            14            1.09          0.71           0.55      -0.17
#
#    A_U_R_PCC  A_U_L_PCC  cog_fail_total
# 0       0.02      -0.16              14
# 1       0.57       0.64              31
# 2      -0.85      -0.73              27
# 3      -0.77      -1.19              36
# 4      -0.45       0.02              21

# %%
df[['HIV', 'CB']]
df['HIV-status'] = df['HIV'].map({1: 'HIV-', 2: 'HIV+'})
df['CB-status'] = df['CB'].map({1: 'non-user', 2: 'user'})
df['group'] = df['HIV-status'] + ', ' + df['CB-status']

# We need a separate dataframe for each group
hiv_pos_df = df.loc[df['HIV-status'] == 'HIV+']
hiv_neg_df = df.loc[df['HIV-status'] == 'HIV-']

# %%
# We need a separate dataframe for each group
hiv_pos_df = df.loc[df['HIV-status'] == 'HIV+']
hiv_neg_df = df.loc[df['HIV-status'] == 'HIV-']

# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='cog_fail_total', y='A_U_L_PCC', 
                      data=hiv_pos_df, kind='reg',
                      color='purple', label='HIV positive',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_L_PCC', data=hiv_neg_df, ax=ax_joint,
            color='green', label='HIV negative', scatter_kws=dict(edgecolor='white', s=50, linewidth=0.6), truncate=False, ci=None)

# Add the full sample central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_L_PCC', data=df, ax=ax_joint,
            color='darkslategray', label='all', truncate=False, scatter=False)

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([0, 20, 40, 60, 80, 100])
ax_joint.set_xlim(-2,100)
ax_joint.set_yticks([-4, -2, 0, 2, 4])
ax_joint.set_ylim(-4, 4)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_xlabel('CFQ', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
#fig.set_size_inches((8, 6))
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle("")
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/L_PCC_A_U_cog_fail')
fig.show()

#######################################################################


# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='cog_fail_total', y='A_U_R_PFC', 
                      data=hiv_pos_df, kind='reg',
                      color='purple', label='HIV positive',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_R_PFC', data=hiv_neg_df, ax=ax_joint,
            color='green', label='HIV negative', scatter_kws=dict(edgecolor='white', s=50, linewidth=0.6), truncate=False, ci=None)

# Add the full sample central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_R_PFC', data=df, ax=ax_joint,
            color='darkslategray', label='all', truncate=False, scatter=False, ci=None)


# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([0, 20, 40, 60, 80, 100])
ax_joint.set_xlim(-2,100)
ax_joint.set_yticks([-4, -2, 0, 2])
ax_joint.set_ylim(-4, 2)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_xlabel('CFQ', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
#fig.set_size_inches((8, 6))
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle("")
ax_joint.lines[2].set_linestyle(":")
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/R_PFC_A_U_cog_fail')
fig.show()

#######################################################################

# We need a separate dataframe for each group
hiv_pos_df = df.loc[df['HIV-status'] == 'HIV+']
hiv_neg_df = df.loc[df['HIV-status'] == 'HIV-']

# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='cog_fail_total', y='A_U_R_Insula', 
                      data=hiv_pos_df, kind='reg',
                      color='purple', label='HIV positive',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_R_Insula', data=hiv_neg_df, ax=ax_joint,
            color='green', label='HIV negative', scatter_kws=dict(edgecolor='white', s=50, linewidth=0.6), truncate=False, ci=None)

# Add the full sample central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_R_Insula', data=df, ax=ax_joint,
            color='darkslategray', label='all', truncate=False, scatter=False, ci=None)

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([0, 20, 40, 60, 80, 100])
ax_joint.set_xlim(-2,100)
ax_joint.set_yticks([-2, 0, 2, 4])
ax_joint.set_ylim(-2, 4)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_xlabel('CFQ', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
#fig.set_size_inches((8, 6))
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle("")
ax_joint.lines[2].set_linestyle(":")
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/R_insula_A_U_cog_fail')
fig.show()


# We need a separate dataframe for each group
hiv_pos_df = df.loc[df['HIV-status'] == 'HIV+']
hiv_neg_df = df.loc[df['HIV-status'] == 'HIV-']

# Then we make the jointplot for one of the groups only
jgrid = sns.jointplot(x='cog_fail_total', y='A_U_R_Putamen', 
                      data=hiv_pos_df, kind='reg',
                      color='purple', label='HIV positive',
                      joint_kws=dict(scatter_kws=dict(edgecolor='white', s=50)),
                      marginal_kws=dict(hist=False, kde_kws={'shade': True}),  # you can control axes with dicts
                      xlim=(-100, 500), ylim=(-100, 500), truncate=False, ci=None)  # note the huge limits
fig = jgrid.fig
ax_joint = jgrid.ax_joint
ax_x = jgrid.ax_marg_x
ax_y = jgrid.ax_marg_y

# Add the HIV-negative central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_R_Putamen', data=hiv_neg_df, ax=ax_joint,
            color='green', label='HIV negative', scatter_kws=dict(edgecolor='white', s=50, linewidth=0.6), truncate=False, ci=None)

# Add the full sample central regression plot to the joint axis
sns.regplot(x='cog_fail_total', y='A_U_R_Putamen', data=df, ax=ax_joint,
            color='darkslategray', label='all', truncate=False, scatter=False, ci=None)

# Clean up the axes
ax_y.set_ylabel(None)
ax_x.set_xlabel(None)
ax_joint.set_xticks([0, 20, 40, 60, 80, 100])
ax_joint.set_xlim(-2,100)
ax_joint.set_yticks([-2, 0, 2, 4])
ax_joint.set_ylim(-2, 4)
ax_joint.tick_params(axis='both', which='major', labelsize=16)
# Add a legend
ax_joint.legend(fontsize=16)
ax_joint.spines['left'].set_linewidth(2.5)
ax_joint.spines['bottom'].set_linewidth(2.5)
ax_joint.set_xlabel('CFQ', fontsize=20, fontweight='bold')
ax_joint.set_ylabel(r'AWARE-UNAWARE $\beta$', fontsize=20, fontweight='bold')
#fig.set_size_inches((8, 6))
ax_joint.lines[0].set_linestyle("")
ax_joint.lines[1].set_linestyle("")
ax_joint.lines[2].set_linestyle(":")
ax_joint.tick_params(axis='both', which='major', labelsize=16,direction='out', length=5, left=True, bottom=True, width=2.5)
ax_joint.legend().set_visible(False)
fig.set_size_inches((4.5, 4))
fig.tight_layout()
fig.savefig(fname='./figure_3/R_put_A_U_cog_fail')
fig.show()
# Out:
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:96: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:147: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /Users/jflanner/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:197: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
